# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/mixed_variable.csv')

# %%
df.dtypes
# Out:
# Ticket_ID          object
# Coach_Class        object
# Passenger_Age       int64
# Boarding_City      object
# Ticket_Price      float64
# Travel_Partner     object
# dtype: object

# %%
df.head()
# Out:
#   Ticket_ID Coach_Class  Passenger_Age Boarding_City  Ticket_Price  \
# 0       A71     Economy             51       Kolkata        737.06
# 1       B27      Luxury             16         Delhi       3014.13
# 2      A109     Sleeper             66        Mumbai       1473.96
# 3       A56    Business             12        Mumbai       1863.96
# 4      A144     Economy             25        Mumbai        763.35
#
#   Travel_Partner
# 0              A
# 1              2
# 2              1
# 3              4
# 4              A

# %%
df['Travel_Partner'].unique()
# Out:
# array(['A', '2', '1', '4', '3', '6', '5'], dtype=object)

# %%
fig = df['Travel_Partner'].value_counts().plot(kind='bar')
fig.set_title('Travel Partner')
# Out:
# Text(0.5, 1.0, 'Travel Partner')

# %%
df['numerical'] = pd.to_numeric(df['Travel_Partner'], errors='coerce',downcast='integer')

# %%
df['categorical'] = np.where(df['numerical'].isnull(),df['Travel_Partner'],np.nan)

# %%
df.head()
# Out:
#   Ticket_ID Coach_Class  Passenger_Age Boarding_City  Ticket_Price  \
# 0       A71     Economy             51       Kolkata        737.06
# 1       B27      Luxury             16         Delhi       3014.13
# 2      A109     Sleeper             66        Mumbai       1473.96
# 3       A56    Business             12        Mumbai       1863.96
# 4      A144     Economy             25        Mumbai        763.35
#
#   Travel_Partner  numerical categorical
# 0              A        NaN           A
# 1              2        2.0         NaN
# 2              1        1.0         NaN
# 3              4        4.0         NaN
# 4              A        NaN           A

# %%
df['cabin_num'] = df['Ticket_ID'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3745814173.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['cabin_num'] = df['Ticket_ID'].str.extract('(\d+)')

# %%
df.head()
# Out:
#   Ticket_ID Coach_Class  Passenger_Age Boarding_City  Ticket_Price  \
# 0       A71     Economy             51       Kolkata        737.06
# 1       B27      Luxury             16         Delhi       3014.13
# 2      A109     Sleeper             66        Mumbai       1473.96
# 3       A56    Business             12        Mumbai       1863.96
# 4      A144     Economy             25        Mumbai        763.35
#
#   Travel_Partner  numerical categorical cabin_num
# 0              A        NaN           A        71
# 1              2        2.0         NaN        27
# 2              1        1.0         NaN       109
# 3              4        4.0         NaN        56
# 4              A        NaN           A       144

# %%
df['cabun_cat'] = df['Ticket_ID'].str[0]

# %%
df.head()
# Out:
#   Ticket_ID Coach_Class  Passenger_Age Boarding_City  Ticket_Price  \
# 0       A71     Economy             51       Kolkata        737.06
# 1       B27      Luxury             16         Delhi       3014.13
# 2      A109     Sleeper             66        Mumbai       1473.96
# 3       A56    Business             12        Mumbai       1863.96
# 4      A144     Economy             25        Mumbai        763.35
#
#   Travel_Partner  numerical categorical cabin_num cabun_cat
# 0              A        NaN           A        71         A
# 1              2        2.0         NaN        27         B
# 2              1        1.0         NaN       109         A
# 3              4        4.0         NaN        56         A
# 4              A        NaN           A       144         A

# %%
df['cabun_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cabun_cat'>

# %% [markdown]
# # Date and **Time**
