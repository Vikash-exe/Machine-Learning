# %%
import numpy as np

# %%
a=np.array(5)

# %%
print(a)
# Out:
# 5

# %%
a.ndim
# Out:
# 0

# %%
arr = np.array([1,2,3,4,5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr.ndim
# Out:
# 1

# %%
arr2=np.array([[1,2,3],[4,5,6]])

# %%
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2.ndim
# Out:
# 2

# %%
import zipfile
import os

# %%
import zipfile

zip_path = "/content/Data1/archive.zip"
extract_path = "/content/Data1"  # folder to extract into

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import pandas as pd
df = pd.read_csv('/content/Data1/stock_details_5_years.csv')

# %%
df
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# ...

# %%
df.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594   43.083508
# 1  2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595  104.636131
# 2  2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998   54.729000
# 3  2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501   83.678497
# 4  2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195   39.037853
#
#       Volume  Dividends  Stock Splits Company
# 0  167080000       0.00           0.0    AAPL
# 1   28123200       0.00           0.0    MSFT
# 2   31004000       0.00           0.0   GOOGL
# 3  132264000       0.00           0.0    AMZN
# 4   54917200       0.04           0.0    NVDA

# %%
df.shape
# Out:
# (602962, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602962 entries, 0 to 602961
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          602962 non-null  object
#  1   Open          602962 non-null  float64
#  2   High          602962 non-null  float64
#  3   Low           602962 non-null  float64
#  4   Close         602962 non-null  float64
#  5   Volume        602962 non-null  int64
#  6   Dividends     602962 non-null  float64
#  7   Stock Splits  602962 non-null  float64
#  8   Company       602962 non-null  object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 41.4+ MB

# %%
ndf = df.iloc[:,1:]
ndf.head()
# Out:
#          Open        High         Low       Close     Volume  Dividends  \
# 0   43.829761   43.863354   42.639594   43.083508  167080000       0.00
# 1  104.769074  105.519257  103.534595  104.636131   28123200       0.00
# 2   54.176498   55.007500   54.099998   54.729000   31004000       0.00
# 3   83.749496   84.499496   82.616501   83.678497  132264000       0.00
# 4   39.692784   40.064904   38.735195   39.037853   54917200       0.04
#
#    Stock Splits Company
# 0           0.0    AAPL
# 1           0.0    MSFT
# 2           0.0   GOOGL
# 3           0.0    AMZN
# 4           0.0    NVDA

# %%
df.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594   43.083508
# 1  2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595  104.636131
# 2  2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998   54.729000
# 3  2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501   83.678497
# 4  2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195   39.037853
#
#       Volume  Dividends  Stock Splits Company
# 0  167080000       0.00           0.0    AAPL
# 1   28123200       0.00           0.0    MSFT
# 2   31004000       0.00           0.0   GOOGL
# 3  132264000       0.00           0.0    AMZN
# 4   54917200       0.04           0.0    NVDA

# %%
ndf = df.iloc[1:100,:]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(ndf['Open'],ndf['High'],ndf['Low'])

# %%
x = ndf.iloc[:100,1:3]
y = ndf.iloc[:100,-4]

# %%
x
# Out:
#            Open         High
# 1    104.769074   105.519257
# 2     54.176498    55.007500
# 3     83.749496    84.499496
# 4     39.692784    40.064904
# 5    135.919998   139.990005
# ..          ...          ...
# 95   171.963333   173.970001
# 96  1866.000000  1885.150024
# 97    52.110001    52.250000
# 98    84.054019    85.754840
# 99    59.386800    59.474923
#
# [99 rows x 2 columns]

# %%
y
# Out:
# 1      28123200
# 2      31004000
# 3     132264000
# 4      54917200
# 5      24238700
#         ...
# 95      1615800
# 96       358100
# 97      1100000
# 98      6013900
# 99      1589200
# Name: Volume, Length: 99, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.2)
# Out:
# [          Open        High
#  11  197.318661  200.990960
#  98   84.054019   85.754840
#  31   77.506613   79.218716
#  33   48.835189   49.084842
#  82   45.716359   46.086395
#  ..         ...         ...
#  22  163.608448  164.291218
#  53   92.116129   94.185865
#  14   89.127160   89.871269
#  81   39.549692   39.647964
#  69  135.975210  136.696170
#
#  [79 rows x 2 columns],
#             Open         High
#  5    135.919998   139.990005
#  34   151.234587   151.467672
#  68    55.518413    56.395550
#  52    34.479461    35.334765
#  28    70.472351    71.517441
#  12    19.554069    19.699040
#  20   157.362338   157.780666
#  66   176.240005   181.809998
#  96  1866.000000  1885.150024
#  25   121.519997   122.320000
#  26    63.217048    64.273534
#  44    42.290426    42.351476
#  21   246.360001   252.250000
#  75   130.247004   132.548669
#  49    35.075914    35.914412
#  43   158.080002   159.000000
#  45    22.980000    23.400000
#  40    35.014327    35.425952
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2)

# %%
X_train
# Out:
#           Open        High
# 50  113.472299  114.834946
# 98   84.054019   85.754840
# 68   55.518413   56.395550
# 8   135.973059  135.982718
# 12   19.554069   19.699040
# ..         ...         ...
# 78   72.212094   72.596454
# 91  372.332609  374.251219
# 54  199.985973  202.875208
# 21  246.360001  252.250000
# 55   39.998901   40.259434
#
# [79 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)
x_train,x_test
# Out:
# (array([[-7.61986581e-02, -7.60956401e-02],
#         [-2.15293626e-01, -2.12099938e-01],
#         [-3.50215154e-01, -3.49409950e-01],
#         [ 3.01890240e-02,  2.28100512e-02],
#         [-5.20261106e-01, -5.21035290e-01],
#         [-2.09401391e-01, -2.12231250e-01],
#         [-4.37097381e-01, -4.38639556e-01],
#         [ 1.31321418e-01,  1.24756537e-01],
#         [ 2.20578460e-01,  2.37138946e-01],
#         [-3.94516772e-01, -3.95989231e-01],
#         [ 7.22143974e-01,  7.45422727e-01],
#         [-1.09778302e-01, -1.04336344e-01],
#         [-4.54224270e-01, -4.54657892e-01],
#         [-4.11799712e-01, -4.13823704e-01],
#         [-3.56559970e-01, -3.55901700e-01],
#         [-5.03337693e-01, -5.04817595e-01],
#         [-2.77232481e-01, -2.79943122e-01],
#         [-4.12759478e-01, -4.15092461e-01],
#         [ 1.34714664e-01,  1.30459220e-01],
#         [-4.01959147e-01, -4.04694829e-01],
#         [-2.25854575e-01, -2.28687657e-01],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
y_train = scaler.fit_transform(Y_train.values.reshape(-1, 1))
y_test = scaler.transform(Y_test.values.reshape(-1, 1))
y_train,y_test
# Out:
# (array([[ 0.0346376 ],
#         [-0.22316597],
#         [-0.29845671],
#         [-0.0767664 ],
#         [-0.3962026 ],
#         [-0.2272249 ],
#         [-0.49900744],
#         [-0.31325389],
#         [-0.4515356 ],
#         [ 0.24475007],
#         [ 0.28046224],
#         [-0.29405553],
#         [-0.16740514],
#         [ 0.07365467],
#         [ 1.11323814],
#         [ 1.92644133],
#         [-0.25403309],
#         [ 0.71689082],
#         [ 0.55323412],
#         [ 0.36712762],
#         [-0.21712303],
#         [-0.29786312],
#         [-0.50940343],
#         [-0.02168971],
#         [-0.50693278],
#         [ 0.84913039],
#         [-0.44114496],
#         [-0.17753375],
#         [-0.11516313],
#         [-0.52562311],
#         [-0.33952731],
#         [-0.45836466],
#         [-0.4022188 ],
#         [-0.53805659],
#         [-0.50292198],
#         [-0.03109675],
#         [-0.30310924],
#         [-0.37912514],
#         [-0.46350918],
#         [-0.12962875],
# ...

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test,y_pred)
print(r2)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# 0.03637376021548777
# Mean Squared Error: 0.47982782119890804

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train,y_train,clf=clf,legend=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1588463522.py in <cell line: 0>()
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(x_train,y_train,clf=clf,legend=2)
#
# /usr/local/lib/python3.12/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     159     """
#     160
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
#     163
#
# /usr/local/lib/python3.12/dist-packages/mlxtend/utils/checking.py in check_Xy(X, y, y_int)
#      18
#      19     if "int" not in str(y.dtype):
# ---> 20         raise ValueError(
# ...

# %%
df
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# ...

# %%
df = pd.read_csv('/content/Data1/stock_details_5_years.csv',parse_dates=['Date'])

# %%
df["Date"] = pd.to_datetime(df["Date"], utc=True)

# %%
df
# Out:
#                             Date        Open        High         Low  \
# 0      2018-11-29 05:00:00+00:00   43.829761   43.863354   42.639594
# 1      2018-11-29 05:00:00+00:00  104.769074  105.519257  103.534595
# 2      2018-11-29 05:00:00+00:00   54.176498   55.007500   54.099998
# 3      2018-11-29 05:00:00+00:00   83.749496   84.499496   82.616501
# 4      2018-11-29 05:00:00+00:00   39.692784   40.064904   38.735195
# ...                          ...         ...         ...         ...
# 602957 2023-11-29 05:00:00+00:00   26.360001   26.397499   26.120001
# 602958 2023-11-29 05:00:00+00:00   27.680000   28.535000   27.680000
# 602959 2023-11-29 05:00:00+00:00   75.940002   76.555000   75.257500
# 602960 2023-11-29 05:00:00+00:00   45.230000   45.259998   44.040001
# 602961 2023-11-29 05:00:00+00:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# ...

# %%
df.dtypes
# Out:
# Date            datetime64[ns, UTC]
# Open                        float64
# High                        float64
# Low                         float64
# Close                       float64
# Volume                        int64
# Dividends                   float64
# Stock Splits                float64
# Company                      object
# dtype: object

# %%
def rename(name):
  if name == 'NVDA':
    return "NVIDIA"
  else :
    return name

# %%
ndf = pd.read_csv('/content/Data1/stock_details_5_years.csv',converters={'Company':rename})
ndf
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# ...
