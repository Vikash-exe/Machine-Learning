# %%
import pandas as pd
df = pd.read_csv('/content/Titanic-Dataset.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-53991253.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/Titanic-Dataset.csv')
#       3 df.head()
#
# ...

# %%
# Uninstall pandas-profiling as it's not compatible with Python 3.12
# !pip uninstall -y pandas-profiling
# Install ydata-profiling, the successor library, which supports newer Python versions
# !pip install ydata-profiling
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.
# ...

# %%
dfn = pd.read_csv('/content/Iris.csv')

# %%
dfn.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(dfn)
prof.to_file(output_file='output_iris.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # standerdization

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'] , test_size=0.2 ,random_state=0)

# %%
X_test.shape , X_train.shape
# Out:
# ((80, 2), (320, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[-7.98950822e-01,  4.94607583e-01],
#        [-2.12648508e-02, -5.77359062e-01],
#        [-3.12897090e-01,  1.46942725e-01],
#        [-7.98950822e-01,  2.62831011e-01],
#        [-3.12897090e-01, -5.77359062e-01],
#        [-1.09058306e+00, -1.44652121e+00],
#        [-7.01740076e-01, -1.59138156e+00],
#        [-2.15686344e-01,  2.14601566e+00],
#        [-1.96547978e+00, -5.58617754e-02],
#        [ 8.53631867e-01, -7.80163563e-01],
#        [-7.98950822e-01, -6.06331134e-01],
#        [-9.93372315e-01, -4.32498705e-01],
#        [-1.18475597e-01, -4.32498705e-01],
#        [ 7.59458956e-02,  2.04886868e-01],
#        [-1.77105829e+00,  4.65635512e-01],
#        [-6.04529329e-01,  1.36376973e+00],
#        [-1.18475597e-01,  2.04886868e-01],
#        [-1.86826903e+00,  4.36663440e-01],
#        [ 1.63131784e+00,  1.74040666e+00],
#        [-3.12897090e-01, -1.38857706e+00],
#        [-3.12897090e-01, -6.64275277e-01],
#        [ 8.53631867e-01,  2.14601566e+00],
# ...

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
X_test_scaled.head()
# Out:
#         Age  EstimatedSalary
# 0 -0.798951         0.494608
# 1 -0.021265        -0.577359
# 2 -0.312897         0.146943
# 3 -0.798951         0.262831
# 4 -0.312897        -0.577359

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
X_test_scaled.head()
# Out:
#         Age  EstimatedSalary
# 0 -0.798951         0.494608
# 1 -0.021265        -0.577359
# 2 -0.312897         0.146943
# 3 -0.798951         0.262831
# 4 -0.312897        -0.577359

# %% [markdown]
# # Normalization

# %%
df = pd.read_csv('/content/wine_data1.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality wine_type
# 0      9.4        6       red
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df.drop('wine_type',axis=1))

# %%
df_scaled = pd.DataFrame(df_scaled, columns=df.drop('wine_type',axis=1).columns)
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.424242          0.527473     0.000000        0.073684   0.081761
# 1       0.484848          0.725275     0.000000        0.147368   0.150943
# 2       0.484848          0.593407     0.071429        0.115789   0.132075
# 3       1.000000          0.065934     1.000000        0.073684   0.078616
# 4       0.424242          0.527473     0.000000        0.073684   0.081761
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.163265              0.167883  0.745763  0.546512   0.090909
# 1             0.448980              0.408759  0.576271  0.186047   0.200000
# 2             0.244898              0.313869  0.610169  0.255814   0.172727
# 3             0.285714              0.357664  0.779661  0.139535   0.109091
# 4             0.163265              0.167883  0.745763  0.546512   0.090909
#
#     alcohol   quality
# 0  0.097561  0.666667
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality wine_type
# 0      9.4        6       red
# ...

# %%
import numpy as np

# %%
np.round(df_scaled.describe(),2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count          46.00             46.00        46.00           46.00
# mean            0.45              0.37         0.31            0.16
# std             0.16              0.18         0.29            0.19
# min             0.00              0.00         0.00            0.00
# 25%             0.39              0.24         0.04            0.06
# 50%             0.45              0.41         0.26            0.09
# 75%             0.50              0.48         0.50            0.14
# max             1.00              1.00         1.00            1.00
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# count      46.00                46.00                 46.00    46.00  46.00
# mean        0.17                 0.26                  0.31     0.59   0.35
# std         0.22                 0.22                  0.25     0.20   0.18
# ...

# %%
sns.kdeplot(df_scaled['alcohol'],color='red')
sns.kdeplot(df_scaled['volatile acidity'],color='blue')
sns.kdeplot(df_scaled['residual sugar'],color='green')
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality wine_type
# 0      9.4        6       red
# ...

# %%
df = pd.read_csv('/content/customer.csv')
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
x_train.head()
# Out:
#      review education
# 12     Poor    School
# 4   Average        UG
# 42     Good        PG
# 49     Good        UG
# 34  Average    School

# %%
y_train.head()
# Out:
# 12     No
# 4      No
# 42    Yes
# 49     No
# 34     No
# Name: purchased, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train = oe.transform(x_train)
x_test = oe.transform(x_test)

# %%
x_train
# Out:
# array([[0., 0.],
#        [1., 1.],
#        [2., 2.],
#        [2., 1.],
#        [1., 0.],
#        [0., 0.],
#        [1., 1.],
#        [2., 2.],
#        [2., 2.],
#        [1., 0.],
#        [0., 1.],
#        [1., 1.],
#        [0., 2.],
#        [2., 1.],
#        [0., 1.],
#        [0., 0.],
#        [1., 1.],
#        [2., 0.],
#        [0., 2.],
#        [1., 2.],
#        [1., 1.],
#        [2., 2.],
#        [2., 1.],
#        [2., 0.],
#        [1., 0.],
#        [0., 1.],
#        [2., 2.],
#        [2., 0.],
#        [1., 2.],
#        [1., 2.],
#        [2., 1.],
#        [0., 2.],
#        [0., 2.],
#        [1., 0.],
#        [0., 2.],
#        [2., 2.],
#        [2., 1.],
#        [0., 2.],
#        [2., 0.],
#        [0., 2.]])

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_test
# Out:
# array([0, 1, 1, 1, 0, 1, 1, 0, 0, 1])

# %%
y_train = pd.DataFrame(y_train,columns=['customer'])
y_test = pd.DataFrame(y_test,columns=['customer'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2639507090.py in <cell line: 0>()
# ----> 1 y_train = pd.DataFrame(y_train,columns=['customer'])
#       2 y_test = pd.DataFrame(y_test,columns=['customer'])
#
# NameError: name 'pd' is not defined
